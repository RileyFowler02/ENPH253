# %% [markdown]
# 2. Theoretical comparison

# %%
import numpy as np
import matplotlib.pyplot as plt

# angle data
voltages = np.array([
2.61 ,

2.59 ,

2.54 ,

2.51 ,

2.48 ,

2.44 ,

2.42 ,

2.38 ,

2.35 ,

2.32 ,

2.65 ,

2.68 ,

2.71 ,

2.74 ,

2.77 ,

2.82 ,

2.85 ,

2.88 ,

2.92 

])

angles = np.array([
0.00 ,

-5.00 ,

-10.00 ,

-15.00 ,

-20.00 ,

-25.00 ,

-30.00 ,

-35.00 ,

-40.00 ,

-45.00 ,

+5.00 ,

+10.00 ,

+15.00 ,

+20.00 ,

+25.00 ,

+30.00 ,

+35.00 ,

+40.00 ,

+45.00 

])

xs = np.linspace(min(voltages),max(voltages), num=100)
coeffs_1, R1, _, _, _ = np.polyfit(voltages, angles, 1, full=True)
m = coeffs_1[0]
b = coeffs_1[1]

plt.figure()
plt.figure(figsize=(10,6))
plt.plot(xs, (m*xs)+b, 'r', label = f'Plot of voltage vs angle from maximum peak: y={m:.2e}x {b:.2e}')
plt.errorbar(voltages, angles, yerr = 0, xerr = 0 , fmt = 'o', label='Experimental data')
plt.grid(True)
plt.ylabel('Angle (degrees)')
plt.xlabel('Voltage (V)')
plt.title("Plot of angle as a function of voltage")
plt.legend(loc = 'best')
plt.show()

print(f"Conversion factor: Angle = {m:.2f} x V  {b:.2f}")
# Out:
# Conversion factor: Angle = 150.18 x V  -392.52

# %% [markdown]
# 3. Theoretical Comparison

# %% [markdown]
# data

# %%
six_raw = """0.0485574
0.0601970
0.0953819
0.0960507
0.1191220
0.1427190
0.1350660
0.1135740
0.1159440
0.1610470
0.2292970
0.3344390
0.3819840
0.4102230
0.4492740
0.4579270
0.4572530
0.4311290
0.3851150
0.2990400
0.1343020
0.0818970
0.1646030
0.1791650
0.1224560
0.0524595
0.0476632
0.0587060
0.1131960
0.1182480
0.0569115
0.0921670
0.2285280
0.3031460
0.2780800
0.2905500
0.3267920
0.5910480
1.0277000
0.9018250
0.6708230
0.9259150
1.1712000
1.1361700
1.1385500
1.1662200
1.1731100
1.1308100
0.9643910
0.8151590
0.5435800
0.2495720
0.2942790
0.3240870
0.1584290
0.1342050
0.1044630
0.1244110
0.2048900
0.1557490
0.1711040
0.3497850
0.3931270
0.3706160
0.3317380
0.3382760
0.4110400
0.4869040
0.6621820
0.8330110
0.9694950
1.0630700
1.2028500
1.1866400
1.2863800
1.3781400
1.4312500
1.4645600
1.4921000
1.4624200
1.4526000
1.3583300
1.2532500
1.1131600
0.9834170
0.7337330
0.5489220
0.3853460
0.3863270
0.2966690
0.3189990
0.3408040
0.3885700
0.4162640
0.3879760
0.2945270
0.2241610
0.1846530
0.1654100
0.2066750
0.2204760
0.2131230
0.1619750
0.1056730
0.0791505
0.0643980
0.0884376
0.1398790
0.1806360
0.1722860
0.1637750
0.1291490
0.0939039
0.1513530
0.1612970
0.2133980
0.2918480
0.3189930
0.3267210
0.3303920
0.3329720
0.2659650
0.2827130
0.3093460
0.4303210
2.4904900
2.4837000
2.4765800
2.4699200
2.4640500
2.4575900
2.4505800
2.4441600
2.4345500
2.4341800
2.4283600
2.4189000
2.4120200
2.4064700
2.3993500
2.3912200
2.3854900
2.3796000
2.3723500
2.3645300
2.3581600
2.3505000
2.3427400
2.3356300
2.3293000
2.3236200
"""

def convert_list(input_string):
    lines = input_string.split()
    numbers = [float(i) for i in lines]
    return np.array(numbers)

i6, i4, i2, i1, i0 = convert_list(six_raw),  convert_list(four_raw),  convert_list(two_raw),  convert_list(one_raw),  convert_list(zero_raw)
v6, v4, v2, v1, v0 = convert_list(six_v_raw),  convert_list(four_v_raw),  convert_list(two_v_raw),  convert_list(one_v_raw),  convert_list(zero_v_raw)

a6, a4, a2, a1, a0 = i6**2, i4**2, i2**2, i1**2, i0**2

def getangle(voltage): 
    return (voltage*m + b)*np.pi/180

t6, t4, t2, t1, t0 = getangle(v6), getangle(v4), getangle(v2), getangle(v1), getangle(v0)

print(np.max(a6), np.max(a4), np.max(a2), np.max(a1), np.max(a0))
print(np.max(t6), np.max(t4), np.max(t2), np.max(t1), np.max(t0))
# Out:
# 2.22636241 1.3100404849000002 0.35832315720100005 0.124945282576 0.00717165084736
# 0.744837506711752 0.7534348365540944 0.8185176719154752 0.5816455079360917 0.5739917874666906

# %% [markdown]
# constants

# %%
import numpy as np
d = 3.38 # distance from the transmitter to the receiver
DC_PS_voltage = 2.5 # DC level of the variable power supply
osc_freq = 39.65 * 1000 # matching the receiver's resonance frequency
conv_factor = 0.0067 # Slope of the DC voltage as a function of the position
slit_spacing = 29.9/1000 # distance between the slits
slit_width = 0.926/100 # width between the slits
ambient_temp = 25 # ambient temperature measured in the room

# wavelength of sound
v_air = 331.3 * np.sqrt(1 + ambient_temp/273.15)
wavelength = v_air / osc_freq
print(wavelength)

angle_degrees = 45
angle_radians = np.radians(angle_degrees)
print(angle_radians)

print(719.9*0.000926*np.sin(angle_radians))
# Out:
# 0.008729614157692394
# 0.7853981633974483
# 0.471376755064757

# %% [markdown]
# (a)

# %%
# finding phi at a given angle
k = 2 * np.pi / wavelength
print(k)
def phi(angle):
    return k * slit_width * np.sin(angle)

# finding the expected amplitude versus angle for each data set
def beta(angle):
    return k * slit_spacing * np.sin(angle)

max_height = np.array([1.49, 1.14, 5.99e-1, 3.53e-1, 2.09e-1])
N = np.array([6.,4.,2.,1.,0.])
A_N = []
for i in range(len(N)):
    if N[i] != 0:  # Avoid division by zero
        A_N.append(max_height[i] / N[i])

# generating angles from -45 to 45 degrees
angles = np.linspace(-.7, .7, 1000)

# zero slit
expected_amplitude_0 = np.zeros_like(angles)

# one slit
A_N_1 = A_N[3]
N_1 = N[3]

expected_amplitude_1 = A_N_1 * np.sin(phi(angles)/2)**2 / (phi(angles)/2)**2 * np.sin(N_1 * beta(angles)/2)**2 / np.sin(beta(angles)/2)**2

# two slits
A_N_2 = A_N[2]
N_2 = N[2]

expected_amplitude_2 = A_N_2 * np.sin(phi(angles)/2)**2 / (phi(angles)/2)**2 * np.sin(N_2 * beta(angles)/2)**2 / np.sin(beta(angles)/2)**2

# four slits
A_N_4 = A_N[1]
N_4 = N[1]

expected_amplitude_4 = A_N_4 * np.sin(phi(angles)/2)**2 / (phi(angles)/2)**2 * np.sin(N_4 * beta(angles)/2)**2 / np.sin(beta(angles)/2)**2

# six slits
A_N_6 = A_N[0]
N_6 = N[0]

expected_amplitude_6 = A_N_6 * np.sin(phi(angles)/2)**2 / (phi(angles)/2)**2 * np.sin(N_6 * beta(angles)/2)**2 / np.sin(beta(angles)/2)**2

# Plot for zero slit
plt.figure(figsize=(10, 6))
plt.plot(t0, a0**2, 'ro', label='Observed Amplitude for 0 slits')
plt.plot(angles, expected_amplitude_0, label='Expected Amplitude for 0 slits')
plt.xlabel('Angle (degrees)')
plt.ylabel('Amplitude ($V^2$)')
plt.title('Amplitude vs Angle for 0 slits')
plt.legend()
plt.grid(True)
plt.show()

# Plot for one slit
plt.figure(figsize=(10, 6))
plt.plot(angles, expected_amplitude_1/20, label='Expected Amplitude for 1 slit')
plt.plot(t1, a1**2, 'ro', label='Observed Amplitude for 1 slit')
plt.xlabel('Angle (degrees)')
plt.ylabel('Amplitude ($V^2$)')
plt.title('Expected Amplitude vs Measured Amplitude as Functions of Angle for 1 slit')
plt.legend()
plt.grid(True)
plt.show()

# Plot for two slits
plt.figure(figsize=(10, 6))
plt.plot(angles, expected_amplitude_2/8, label='Expected Amplitude for 2 slits')
plt.plot(t2, a2**2, 'ro', label='Observed Amplitude for 2 slits')
plt.xlabel('Angle (degrees)')
plt.ylabel('Amplitude ($V^2$)')
plt.title('Expected Amplitude vs Measured Amplitude as Functions of Angle for 2 slits')
plt.legend()
plt.grid(True)
plt.show()

# Plot for four slits
plt.figure(figsize=(10, 6))
plt.plot(angles, expected_amplitude_4/2, label='Expected Amplitude for 4 slits')
plt.plot(t4, a4**2, 'ro', label='Observed Amplitude for 4 slits')
plt.xlabel('Angle (degrees)')
plt.ylabel('Amplitude ($V^2$)')
plt.title('Expected Amplitude vs Measured Amplitude as Functions of Angle for 4 slits')
plt.legend()
plt.grid(True)
plt.show()

# Plot for six slits
plt.figure(figsize=(10, 6))
plt.plot(angles, expected_amplitude_6/1.5, label='Expected Amplitude for 6 slits')
plt.plot(t6, a6**2, 'ro', label='Observed Amplitude for 6 slits')
plt.xlabel('Angle (degrees)')
plt.ylabel('Amplitude ($V^2$)')
plt.title('Expected Amplitude vs Measured Amplitude as Functions of Angle for 6 slits')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# 719.7552141113757

# %% [markdown]
# 4.

# %%
# zero slit


# Plot for one slit
plt.figure(figsize=(10, 6))
plt.plot(t1, a1**2, 'ro', label='Observed Amplitude for 1 slit')
plt.plot(t0,10*a0**2, 'bo', label='Observed Amplitude for 0 slit')
plt.xlabel('Angle')
plt.ylabel('Amplitude $V^2$')
plt.title('Comparing Measured Amplitudes for 1 and 0 Slits as Functions of Angle')
plt.legend()
plt.grid(True)
plt.show()
